# %%
import pandas as pd 
import matplotlib.pyplot as ply
import numpy as np
import seaborn as sns
import datetime

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\git 23\real_estate_15000_rows.csv')

# %%
df
# Out:
#        Year  Region  Country       City  Start_Date    End_Date  Stay_Days  \
# 0      2022    Asia    Japan      Delhi  2022-06-20  2022-07-22         32
# 1      2021    Asia    India     Berlin  2021-03-23  2021-05-10         48
# 2      2026  Europe  Germany     Berlin  2026-05-20  2026-07-08         49
# 3      2026  Europe   France     Munich  2026-08-27  2026-10-02         36
# 4      2025   China    China     Berlin  2025-06-03  2025-06-04          1
# ...     ...     ...      ...        ...         ...         ...        ...
# 14995  2026      US      USA      Paris  2026-05-19  2026-06-27         39
# 14996  2026      US      USA  Sao Paulo  2026-04-18  2026-05-31         43
# 14997  2024  Europe  Germany      Paris  2024-04-20  2024-05-02         12
# 14998  2024   China    China    Beijing  2024-04-01  2024-04-21         20
# 14999  2022      US      USA       Rome  2022-02-12  2022-02-22         10
#
# ...

# %%
df[['Country']]
# Out:
#        Country
# 0        Japan
# 1        India
# 2      Germany
# 3       France
# 4        China
# ...        ...
# 14995      USA
# 14996      USA
# 14997  Germany
# 14998    China
# 14999      USA
#
# [15000 rows x 1 columns]
